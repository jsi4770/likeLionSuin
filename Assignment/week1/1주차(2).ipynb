# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 구글 드라이브 연동 코드
from google.colab import drive
drive.mount('/content/drive')

# %%
# 한글 폰트 깨짐 방지 세팅
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
plt.rc('font', family='NanumBarunGothic')

# %%
# 미션 1: 다운받은 수원시 CSV 파일 경로를 복사해서 안에 넣어주세요!
df = pd.read_csv(' 여기에_경로_복사해서_붙여넣기 ,encoding='cp949'')
print(df.head())

# %%
# 미션 2: 그래프 사이즈를 가로 15, 세로 6으로 넓게 펴주세요.
plt.figure(figsize=( , ))

# %%
# 미션 3: x축은 '행정동명', y축은 '20-24세 남성 인구수' 또는 '20-24세 여성 인구수'로 막대그래프를 그려보세요!
# (에러가 나면 컬럼 이름을 df.head()에서 정확히 확인하고 복붙하세요)
sns.barplot(x=' ', y=' ', data=df, errorbar=None)

# %%
plt.xticks(rotation=45)
plt.show()
